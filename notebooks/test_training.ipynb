# %%
import os
from walkability.dataset.dataloader import get_data_loaders
from walkability.train_model import train_model

# %%
BASE_PATH = "/projects/dsci410_510/data/walkability_dataset/"
train_loader, val_loader, test_loader = get_data_loaders(BASE_PATH, name="all", batch_size=32)

model, trainer = train_model(train_loader, val_loader, test_loader)
# Out:
# /home/hsiegel/.conda/envs/walkability/lib/python3.10/site-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /home/hsiegel/.conda/envs/walkability/lib/python3.10/site-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /home/hsiegel/.conda/envs/walkability/lib/python3.10/site-packages/lightning_fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/hsiegel/.conda/envs/walkability/lib/python3.10 ...
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# /home/hsiegel/.conda/envs/walkability/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA A100 80GB PCIe MIG 1g.10gb') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [MIG-f362c60e-230f-5e48-b05b-03d48343058a]
#
#    | Name             | Type                      | Params | Mode  | FLOPs
# --------------------------------------------------------------------------------
# 0  | conv1_1          | Conv2d                    | 896    | train | 0
# 1  | conv1_2          | Conv2d                    | 9.2 K  | train | 0
# 2  | bn1              | BatchNorm2d               | 64     | train | 0
# 3  | pool1            | MaxPool2d                 | 0      | train | 0
# 4  | conv2_1          | Conv2d                    | 18.5 K | train | 0
# 5  | conv2_2          | Conv2d                    | 36.9 K | train | 0
# 6  | bn2              | BatchNorm2d               | 128    | train | 0
# 7  | pool2            | MaxPool2d                 | 0      | train | 0
# 8  | conv3_1          | Conv2d                    | 73.9 K | train | 0
# 9  | conv3_2          | Conv2d                    | 147 K  | train | 0
# 10 | bn3              | BatchNorm2d               | 256    | train | 0
# 11 | pool3            | MaxPool2d                 | 0      | train | 0
# 12 | adaptive_pool    | AdaptiveAvgPool2d         | 0      | train | 0
# 13 | fc1              | Linear                    | 524 K  | train | 0
# 14 | fc2              | Linear                    | 771    | train | 0
# 15 | dropout          | Dropout                   | 0      | train | 0
# 16 | train_accuracy   | MulticlassAccuracy        | 0      | train | 0
# 17 | val_accuracy     | MulticlassAccuracy        | 0      | train | 0
# 18 | test_accuracy    | MulticlassAccuracy        | 0      | train | 0
# 19 | confusion_matrix | MulticlassConfusionMatrix | 0      | train | 0
# --------------------------------------------------------------------------------
# 812 K     Trainable params
# 0         Non-trainable params
# 812 K     Total params
# 3.251     Total estimated model params size (MB)
# 20        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/hsiegel/.conda/envs/walkability/lib/python3.10/site-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /home/hsiegel/.conda/envs/walkability/lib/python3.10/site-packages/torch/utils/data/dataloader.py:430: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Training: |          | 0/? [00:00<?, ?it/s]
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /home/hsiegel/.conda/envs/walkability/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
